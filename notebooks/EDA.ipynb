# %%
import pandas as pd
data = pd.read_csv(r'C:\All_Project\IncomePrice\notebooks\data\adult.data',names = ['age', 'job','fnlwgt','Qualification','education-num','Marital-Status','occupation','relationship','Colour','Gender','capital-gain','capital-loss','hours-per-week','City','Salary'])

df = data.sample(frac=0.25, random_state=42)
df.head()
# Out:
#        age                job  fnlwgt  Qualification  education-num  \
# 14160   27            Private  160178   Some-college             10
# 27048   45          State-gov   50567        HS-grad              9
# 28868   29            Private  185908      Bachelors             13
# 5667    30            Private  190040      Bachelors             13
# 7827    29   Self-emp-not-inc  189346   Some-college             10
#
#             Marital-Status          occupation    relationship  Colour  \
# 14160             Divorced        Adm-clerical   Not-in-family   White
# 27048   Married-civ-spouse     Exec-managerial            Wife   White
# 28868   Married-civ-spouse     Exec-managerial         Husband   Black
# 5667         Never-married   Machine-op-inspct   Not-in-family   White
# 7827              Divorced        Craft-repair   Not-in-family   White
#
#         Gender  capital-gain  capital-loss  hours-per-week            City  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8140 entries, 14160 to 30339
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             8140 non-null   int64
#  1   job             8140 non-null   object
#  2   fnlwgt          8140 non-null   int64
#  3   Qualification   8140 non-null   object
#  4   education-num   8140 non-null   int64
#  5   Marital-Status  8140 non-null   object
#  6   occupation      8140 non-null   object
#  7   relationship    8140 non-null   object
#  8   Colour          8140 non-null   object
#  9   Gender          8140 non-null   object
#  10  capital-gain    8140 non-null   int64
#  11  capital-loss    8140 non-null   int64
#  12  hours-per-week  8140 non-null   int64
#  13  City            8140 non-null   object
#  14  Salary          8140 non-null   object
# dtypes: int64(6), object(9)
# memory usage: 1017.5+ KB

# %%
print(df.describe())
df.describe(include = ['object'])
# Out:
#                age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  8140.000000  8.140000e+03    8140.000000   8140.000000   8140.000000
# mean     38.534029  1.900627e+05      10.054914   1173.860197     82.120762
# std      13.646961  1.065410e+05       2.566248   8017.402818    394.324221
# min      17.000000  1.487800e+04       1.000000      0.000000      0.000000
# 25%      27.000000  1.176622e+05       9.000000      0.000000      0.000000
# 50%      37.000000  1.789710e+05      10.000000      0.000000      0.000000
# 75%      48.000000  2.367890e+05      12.000000      0.000000      0.000000
# max      90.000000  1.268339e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count     8140.000000
# mean        40.590172
# std         12.490020
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
#              job Qualification       Marital-Status       occupation  \
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# fnlwgt            0
# Qualification     0
# education-num     0
# Marital-Status    0
# occupation        0
# relationship      0
# Colour            0
# Gender            0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# City              0
# Salary            0
# dtype: int64

# %%
for i in df.columns:
  print(df[i].unique())
# Out:
# [27 45 29 30 51 58 22 50 43 37 41 46 33 52 38 32 40 31 23 59 18 53 26 28
#  34 25 54 48 72 20 64 60 19 62 49 81 47 36 24 39 63 35 42 55 68 90 57 21
#  17 69 56 44 66 70 67 73 61 78 65 79 80 74 83 84 71 85 75 82 77 76]
# [' Private' ' State-gov' ' Self-emp-not-inc' ' Self-emp-inc'
#  ' Federal-gov' ' Local-gov' ' ?' ' Without-pay']
# [160178  50567 185908 ... 407913 188650 175804]
# [' Some-college' ' HS-grad' ' Bachelors' ' Masters' ' Assoc-acdm'
#  ' 7th-8th' ' 11th' ' Assoc-voc' ' Prof-school' ' 9th' ' 5th-6th' ' 10th'
#  ' Doctorate' ' 12th' ' 1st-4th' ' Preschool']
# [10  9 13 14 12  4  7 11 15  5  3  6 16  8  2  1]
# [' Divorced' ' Married-civ-spouse' ' Never-married' ' Separated'
#  ' Widowed' ' Married-spouse-absent' ' Married-AF-spouse']
# [' Adm-clerical' ' Exec-managerial' ' Machine-op-inspct' ' Craft-repair'
#  ' Prof-specialty' ' Sales' ' Handlers-cleaners' ' Other-service'
#  ' Protective-serv' ' Priv-house-serv' ' Transport-moving' ' ?'
# ...

# %%
import numpy as np

df.replace(' ?',np.nan,inplace=True) #replacing '?' with NaN

# %%
df['occupation'].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Machine-op-inspct',
#        ' Craft-repair', ' Prof-specialty', ' Sales', ' Handlers-cleaners',
#        ' Other-service', ' Protective-serv', ' Priv-house-serv',
#        ' Transport-moving', nan, ' Farming-fishing', ' Tech-support',
#        ' Armed-Forces'], dtype=object)

# %%
df['age'].unique()
# Out:
# array([27, 45, 29, 30, 51, 58, 22, 50, 43, 37, 41, 46, 33, 52, 38, 32, 40,
#        31, 23, 59, 18, 53, 26, 28, 34, 25, 54, 48, 72, 20, 64, 60, 19, 62,
#        49, 81, 47, 36, 24, 39, 63, 35, 42, 55, 68, 90, 57, 21, 17, 69, 56,
#        44, 66, 70, 67, 73, 61, 78, 65, 79, 80, 74, 83, 84, 71, 85, 75, 82,
#        77, 76], dtype=int64)

# %%
df['age'].value_counts()
# Out:
# 36    244
# 31    231
# 35    224
# 34    224
# 25    221
#      ...
# 79      5
# 84      5
# 82      3
# 83      2
# 85      1
# Name: age, Length: 70, dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'job', 'fnlwgt', 'Qualification', 'education-num',
#        'Marital-Status', 'occupation', 'relationship', 'Colour', 'Gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'City', 'Salary'],
#       dtype='object')

# %%
df.head()
# Out:
#        age                job  fnlwgt  Qualification  education-num  \
# 14160   27            Private  160178   Some-college             10
# 27048   45          State-gov   50567        HS-grad              9
# 28868   29            Private  185908      Bachelors             13
# 5667    30            Private  190040      Bachelors             13
# 7827    29   Self-emp-not-inc  189346   Some-college             10
#
#             Marital-Status          occupation    relationship  Colour  \
# 14160             Divorced        Adm-clerical   Not-in-family   White
# 27048   Married-civ-spouse     Exec-managerial            Wife   White
# 28868   Married-civ-spouse     Exec-managerial         Husband   Black
# 5667         Never-married   Machine-op-inspct   Not-in-family   White
# 7827              Divorced        Craft-repair   Not-in-family   White
#
#         Gender  capital-gain  capital-loss  hours-per-week            City  \
# ...

# %%
df.isnull().sum()
# Out:
# age                 0
# job               476
# fnlwgt              0
# Qualification       0
# education-num       0
# Marital-Status      0
# occupation        476
# relationship        0
# Colour              0
# Gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week      0
# City              148
# Salary              0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8140 entries, 14160 to 30339
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             8140 non-null   int64
#  1   job             7664 non-null   object
#  2   fnlwgt          8140 non-null   int64
#  3   Qualification   8140 non-null   object
#  4   education-num   8140 non-null   int64
#  5   Marital-Status  8140 non-null   object
#  6   occupation      7664 non-null   object
#  7   relationship    8140 non-null   object
#  8   Colour          8140 non-null   object
#  9   Gender          8140 non-null   object
#  10  capital-gain    8140 non-null   int64
#  11  capital-loss    8140 non-null   int64
#  12  hours-per-week  8140 non-null   int64
#  13  City            7992 non-null   object
#  14  Salary          8140 non-null   object
# dtypes: int64(6), object(9)
# memory usage: 1017.5+ KB

# %%
# distribution of target variable
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(df['Salary'], bins=30, edgecolor='black')
plt.title('Distribution of Salary')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.show()

# %%
plt.pie(df['Salary'].value_counts(),labels=df['Salary'].value_counts().index,autopct="%1.2f%%")
plt.title("income distribution")
plt.show()

# %%
# histogram for numeric features
import matplotlib.pyplot as plt

numerical_features = df.select_dtypes(include=['int64', 'float64']).columns

for column in numerical_features:
    plt.figure(figsize=(10, 6))
    plt.hist(df[column], bins=30, edgecolor='black')
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
# sns.histplot
for column in numerical_features:
    sns.histplot(df,x=column,hue='Salary')
    plt.show()

# %%
# Bar plots for categorical features
categorical_cols = df.select_dtypes(include = 'object').columns

for col in categorical_cols:
    plt.figure(figsize=(20,10))
    sns.countplot(x=df[col])
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.show()

# %%
# bivariate analysis categoercal-categorical
plt.figure(figsize = (20,12))
sns.countplot(x='Qualification',hue = 'job', data=df)
plt.title('Distribution of Qualification')
plt.xlabel('Qualification')
plt.ylabel('job')
plt.show()

# %%
qualification = df['Qualification'].value_counts()

plt.figure(figsize = (10,15))
plt.pie(qualification,labels=qualification.index,autopct="%1.2f%%",rotatelabels=True)
plt.title("qualification distribution")
plt.show()

# %%
qua_income = df.groupby('Qualification')['Salary']
qua_income.value_counts()
# Out:
# Qualification  Salary
#  10th           <=50K     224
#                 >50K       16
#  11th           <=50K     273
#                 >50K       13
#  12th           <=50K     109
#                 >50K        7
#  1st-4th        <=50K      31
#  5th-6th        <=50K      78
#                 >50K        8
#  7th-8th        <=50K     169
#                 >50K        6
#  9th            <=50K     135
#                 >50K        4
#  Assoc-acdm     <=50K     197
#                 >50K       57
#  Assoc-voc      <=50K     260
#                 >50K       83
#  Bachelors      <=50K     779
#                 >50K      541
#  Doctorate      >50K       73
#                 <=50K      23
#  HS-grad        <=50K    2201
#                 >50K      428
#  Masters        >50K      244
#                 <=50K     189
#  Preschool      <=50K      12
#  Prof-school    >50K      103
#                 <=50K      39
#  Some-college   <=50K    1495
#                 >50K      343
# ...

# %%
plt.figure(figsize = (10,12))
sns.countplot(x='Qualification',hue = 'Salary', data=df)
plt.title('Distribution of Qualification')
plt.xlabel('Qualification')
plt.ylabel('count')
plt.xticks(rotation=90)
plt.show()

# %%
# bar plot for two categorical variables
plt.figure(figsize = (20,10))
sns.countplot(x='age', hue='Salary', data=df)
plt.title('Age vs Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %%
# Bar plot for two categorical variables
plt.figure(figsize=(15,5))
sns.countplot(x='job',hue='Salary',data=df)
plt.title('job vs Salary')
plt.xlabel('job')
plt.ylabel('Salary')
plt.show()

# %%
# countplot for cat-cat
plt.figure(figsize = (15,10))
sns.countplot(x='Gender',hue='job',data = df)
plt.title('Gender vs job')
plt.xlabel('Gender')
plt.ylabel('job')
plt.show()

# %%
gen_job = df.groupby('Gender')['job']
gen_job.value_counts()
# Out:
# Gender   job
#  Female   Private             1931
#           Local-gov            190
#           State-gov            112
#           Self-emp-not-inc      95
#           Federal-gov           83
#           Self-emp-inc          36
#           Without-pay            2
#  Male     Private             3780
#           Self-emp-not-inc     531
#           Local-gov            306
#           Self-emp-inc         229
#           State-gov            205
#           Federal-gov          162
#           Without-pay            2
# Name: job, dtype: int64

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x='hours-per-week', y='Salary', data=data)
plt.title('Salary Distribution by Target')
plt.xlabel('Target')
plt.ylabel('Salary')
plt.show()

# %%
s = pd.crosstab(df['hours-per-week'],df['Salary'],normalize="index")
print(s)
# Out:
# Salary             <=50K      >50K
# hours-per-week
# 1               0.800000  0.200000
# 2               0.714286  0.285714
# 3               1.000000  0.000000
# 4               0.944444  0.055556
# 5               0.923077  0.076923
# ...                  ...       ...
# 90              1.000000  0.000000
# 94              1.000000  0.000000
# 95              0.000000  1.000000
# 98              1.000000  0.000000
# 99              0.814815  0.185185
#
# [84 rows x 2 columns]

# %%
s.plot(kind = 'bar',stacked=True, figsize=(20,15))
# Out:
# <AxesSubplot:xlabel='hours-per-week'>

# %%
df.shape
# Out:
# (8140, 15)

# %%
# Correlation heatmap
plt.figure(figsize=(12, 10))
correlation_matrix = df[numerical_features].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
# Pair plot to numeric feature
sns.pairplot(df)
plt.show()

# %%
#for checking outliers
for feature in numerical_features:
    sns.boxplot(x=df[feature])
    plt.show()

# %%
salary_map = {' <=50K':0,' >50K':1}

df['Salary'] = df['Salary'].map(salary_map)

# %%
df.drop(labels=['fnlwgt','capital-loss'],axis=1,inplace=True)

# %%
col_with_nan = ['job','occupation','City']

for i in col_with_nan:
    df[i].fillna(df[i].mode()[0],inplace=True)

# %%
def whitespace_remover(dataframe):

  for i in dataframe.columns:

    if dataframe[i].dtype == 'object':

      dataframe[i] = dataframe[i].map(str.strip)

    else:

      pass

whitespace_remover(df)

# %%
df.head()
# Out:
#        age               job Qualification  education-num      Marital-Status  \
# 14160   27           Private  Some-college             10            Divorced
# 27048   45         State-gov       HS-grad              9  Married-civ-spouse
# 28868   29           Private     Bachelors             13  Married-civ-spouse
# 5667    30           Private     Bachelors             13       Never-married
# 7827    29  Self-emp-not-inc  Some-college             10            Divorced
#
#               occupation   relationship Colour  Gender  capital-gain  \
# 14160       Adm-clerical  Not-in-family  White  Female             0
# 27048    Exec-managerial           Wife  White  Female             0
# 28868    Exec-managerial        Husband  Black    Male             0
# 5667   Machine-op-inspct  Not-in-family  White  Female             0
# 7827        Craft-repair  Not-in-family  White    Male          2202
#
#        hours-per-week           City  Salary
# ...
